# %% [markdown]
# Setup

# %%
import torch
from src.training.train import main

# %% [markdown]
# Start training

# %%
main()

# %% [markdown]
# Evaluation of best checkpoint

# %%
from src.training.eval import evaluate_checkpoint

evaluate_checkpoint("outputs/checkpoints/best_model.pt")

# %% [markdown]
# Plot some reconstructions

# %%
from src.utils.plot import save_reconstruction_plot
